# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from math import ceil

# %%
# Optional -> to check all the rows and columns
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
data = pd.read_csv('donors.csv')
data.head()
# Out:
# C:\Users\maisd\anaconda3\envs\DMProject\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (9,412) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0     ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE  \
# 0           0  2009-01-01     GRI      0    IL  61081
# 1           1  2014-01-01     BOA      1    CA  91326
# 2           2  2010-01-01     AMH      1    NC  27017
# 3           3  2007-01-01     BRY      0    CA  95953
# 4           4  2006-01-01              0    FL  33176
#
#           DOB NOEXCH  ...    AVGGIFT CONTROLN HPHONE_D RFA_2R RFA_2F RFA_2A  \
# 0  1957-12-01      0  ...   7.741935    95515        0      L      4      E
# 1  1972-02-01      0  ...  15.666667   148535        0      L      2      G
# 2         NaN      0  ...   7.481481    15078        1      L      4      E
# 3  1948-01-01      0  ...   6.812500   172556        1      L      4      E
# 4  1940-01-01      0  ...   6.864865     7112        1      L      2      F
#
#   MDMAUD_R MDMAUD_F MDMAUD_A GEOCODE2
# 0        X        X        X        C
# 1        X        X        X        A
# 2        X        X        X        C
# 3        X        X        X        C
# 4        X        X        X        A
#
# [5 rows x 476 columns]

# %%
# Unnamed: 0 works as an index so we can drop it
data.drop('Unnamed: 0', axis = 1, inplace  = True)
data.head()
# Out:
#       ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE         DOB  \
# 0  2009-01-01     GRI      0    IL  61081                    1957-12-01
# 1  2014-01-01     BOA      1    CA  91326                    1972-02-01
# 2  2010-01-01     AMH      1    NC  27017                           NaN
# 3  2007-01-01     BRY      0    CA  95953                    1948-01-01
# 4  2006-01-01              0    FL  33176                    1940-01-01
#
#   NOEXCH RECINHSE  ...    AVGGIFT CONTROLN HPHONE_D RFA_2R RFA_2F RFA_2A  \
# 0      0           ...   7.741935    95515        0      L      4      E
# 1      0           ...  15.666667   148535        0      L      2      G
# 2      0           ...   7.481481    15078        1      L      4      E
# 3      0           ...   6.812500   172556        1      L      4      E
# 4      0        X  ...   6.864865     7112        1      L      2      F
#
#   MDMAUD_R MDMAUD_F MDMAUD_A GEOCODE2
# 0        X        X        X        C
# 1        X        X        X        A
# 2        X        X        X        C
# 3        X        X        X        C
# 4        X        X        X        A
#
# [5 rows x 475 columns]

# %%
# Dimension of the dataset
data.shape
# Out:
# (95412, 475)

# %%
# Data types of the variables and columns
data.dtypes
# Out:
# ODATEDW     object
# OSOURCE     object
# TCODE        int64
# STATE       object
# ZIP         object
#              ...
# RFA_2A      object
# MDMAUD_R    object
# MDMAUD_F    object
# MDMAUD_A    object
# GEOCODE2    object
# Length: 475, dtype: object

# %%
# Summary Statistics of our variables
data.describe(include='all').T
# Out:
#           count unique         top   freq     mean      std  min  25%  50%  \
# ODATEDW   95412     54  2015-01-01  15358      NaN      NaN  NaN  NaN  NaN
# OSOURCE   95412    896         MBC   4539      NaN      NaN  NaN  NaN  NaN
# TCODE     95412    NaN         NaN    NaN  54.2231  953.844    0    0    1
# STATE     95412     57          CA  17343      NaN      NaN  NaN  NaN  NaN
# ZIP       95412  19938       85351     61      NaN      NaN  NaN  NaN  NaN
# ...         ...    ...         ...    ...      ...      ...  ...  ...  ...
# RFA_2A    95412      4           F  46964      NaN      NaN  NaN  NaN  NaN
# MDMAUD_R  95412      5           X  95118      NaN      NaN  NaN  NaN  NaN
# MDMAUD_F  95412      4           X  95118      NaN      NaN  NaN  NaN  NaN
# MDMAUD_A  95412      5           X  95118      NaN      NaN  NaN  NaN  NaN
# GEOCODE2  95280      5           A  34484      NaN      NaN  NaN  NaN  NaN
#
#           75%    max
# ODATEDW   NaN    NaN
# OSOURCE   NaN    NaN
# TCODE       2  72002
# STATE     NaN    NaN
# ZIP       NaN    NaN
# ...       ...    ...
# RFA_2A    NaN    NaN
# MDMAUD_R  NaN    NaN
# MDMAUD_F  NaN    NaN
# MDMAUD_A  NaN    NaN
# GEOCODE2  NaN    NaN
#
# [475 rows x 11 columns]

# %%
# Check duplicates
any(data.duplicated())
# Out:
# False

# %%
# Count of missing values
data.isna().sum()
# Out:
# ODATEDW       0
# OSOURCE       0
# TCODE         0
# STATE         0
# ZIP           0
#            ...
# RFA_2A        0
# MDMAUD_R      0
# MDMAUD_F      0
# MDMAUD_A      0
# GEOCODE2    132
# Length: 475, dtype: int64

# %%
# Define metric and non 
non_metric_var = pd.DataFrame(data.dtypes).loc[pd.DataFrame(data.dtypes)[0] == 'object'].index.to_list()
metric_var = pd.DataFrame(data.dtypes).loc[pd.DataFrame(data.dtypes)[0] != 'object'].index.to_list()

# %%
# Metric Variables Histograms 
sb.set()

# Create individual axes 
fig, axes = plt.subplots(ceil(len(metric_var)/2), 2, figsize=(20, 900))
plt.subplots_adjust(hspace = 0.18)

# Plot data
for ax, feat in zip(axes.flatten(), metric_var):
    ax.hist(data[feat])
    ax.set_title(feat, y = -0.16)
    
plt.show()

# %%
# Non Numeric Variables
sb.set()

# Prepare figure. Create individual axes where each histogram will be placed
fig, axes = plt.subplots(ceil(len(non_metric_var) / 2), 1, figsize=(20, 100))
plt.subplots_adjust(hspace = 0.18)

# Plot data
for ax, feat in zip(axes.flatten(), non_metric_var):
    sb.countplot(x=data[feat],  ax=ax)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-f6792cf6aa45> in <module>
#      10     sb.countplot(x=data[feat],  ax=ax)
#      11
# ---> 12 plt.show()
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\anaconda3\envs\DMProject\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\envs\DMProject\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\anaconda3\envs\DMProject\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2705                 artists.remove(spine)
#    2706
# -> 2707         self._update_title_position(renderer)
#    2708
#    2709         if not self.axison or inframe:
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\axes\_base.py in _update_title_position(self, renderer)
#    2636                 if (ax.xaxis.get_ticks_position() in ['top', 'unknown']
#    2637                         or ax.xaxis.get_label_position() == 'top'):
# -> 2638                     bb = ax.xaxis.get_tightbbox(renderer)
#    2639                 else:
#    2640                     bb = ax.get_window_extent(renderer)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1112
#    1113         # go back to just this axis's tick labels
# -> 1114         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(
#    1115                     ticks_to_draw, renderer)
#    1116
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     898
#     899         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 900             bbox, info, descent = self._get_layout(self._renderer)
#     901             x, y = self.get_unitless_position()
#     902             x, y = self.get_transform().transform((x, y))
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     291             clean_line, ismath = self._preprocess_math(line)
#     292             if clean_line:
# --> 293                 w, h, d = renderer.get_text_width_height_descent(
#     294                     clean_line, self._fontproperties, ismath=ismath)
#     295             else:
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     235
#     236         flags = get_hinting_flag()
# --> 237         font = self._get_agg_font(prop)
#     238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\backends\backend_agg.py in _get_agg_font(self, prop)
#     271         """
#     272         fname = findfont(prop)
# --> 273         font = get_font(fname)
#     274
#     275         font.clear()
#
# ~\anaconda3\envs\DMProject\lib\site-packages\matplotlib\font_manager.py in get_font(filename, hinting_factor)
#    1412     # Resolving the path avoids embedding the font twice in pdf/ps output if a
#    1413     # single font is selected using two different relative paths.
# -> 1414     filename = os.path.realpath(filename)
#    1415     if hinting_factor is None:
#    1416         hinting_factor = rcParams['text.hinting_factor']
#
# ~\anaconda3\envs\DMProject\lib\ntpath.py in realpath(path)
#     662             # Ensure that the non-prefixed path resolves to the same path
#     663             try:
# --> 664                 if _getfinalpathname(spath) == path:
#     665                     path = spath
#     666             except OSError as ex:
#
# KeyboardInterrupt:
